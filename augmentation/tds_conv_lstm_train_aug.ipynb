# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/C147_247_Project/emg2qwerty-main/
# Out:
# /content/drive/MyDrive/C147_247_Project/emg2qwerty-main

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached https://github.com/kpu/kenlm/archive/master.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
! pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/C147_247_Project/emg2qwerty-main
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: emg2qwerty
#     Found existing installation: emg2qwerty 0.1.0
#     Uninstalling emg2qwerty-0.1.0:
#       Successfully uninstalled emg2qwerty-0.1.0
#   Running setup.py develop for emg2qwerty
# ...

# %%
# Single-user training
# !python -m emg2qwerty.train \
  model=tds_conv_lstm_ctc \
  user=single_user \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=40 \
  +trainer.precision=16 \
  batch_size=32 \
  num_workers=4 \
  checkpoint=null
  # --multirun
# Out:
# [2026-03-12 23:03:27,246][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user testing: baseline TDS + GRU model
# !python -m emg2qwerty.train \
  model=tds_conv_lstm_ctc \
  user=single_user \
  train=False \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  +trainer.precision=16 \
  batch_size=32 \
  num_workers=2 \
  checkpoint="'/content/drive/MyDrive/C147_247_Project/emg2qwerty-main/logs/2026-03-12/08-02-56/checkpoints/epoch=36-step=4440.ckpt'"
# Out:
# [2026-03-12 23:30:46,368][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
